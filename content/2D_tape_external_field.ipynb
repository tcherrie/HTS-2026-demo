# %% [markdown]
# # 2D Tape - external field
#
# This notebooks presents the simulation of a HTS tape using H-formulation.
#
# Short presentation of the test case with a nice figure to illustrate

# %% [markdown]
# ____
# ## 1) Geometry and mesh

# %%
from utils.geometry import mesh_tape_comsol
from ngsolve.webgui import Draw

mesh = mesh_tape_comsol(quarter = True)
print(f"Imported 2D ribbon mesh with {mesh.ne} triangles, {mesh.nedge} edges and {mesh.nv} nodes.")
Draw(mesh)
# Out:
# Imported 2D ribbon mesh with 695 triangles, 1116 edges and 422 nodes.
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# _____
# ## 2) Physical parameters ######################################

# %% [markdown]
# ### a) Default physical parameters

# %%
from ngsolve import pi

mu0 = 4e-7 * pi     # permeability of air (H/m)
rhoair = 1          # resistivity of air approximation (Ω·m)
epsJ = 2.2e-16      # tolerence to avoid the evaluation of zero at a negative power, used in the norm of current density ||J|| = sqrt(Jx^2+Jy^2+Jz^2+epsJ)

# %% [markdown]
# ### b) Definition of the source field

# %%
Bmax = 2e-3         # amplitude (T)
freq = 50           # frequency (Hz)
theta = pi/2        # angular orientation of the source field (rad)

from ngsolve import cos, sin, CoefficientFunction as CF
H_s_dir = Bmax / mu0 * CF((cos(theta), sin(theta)))

Hs = lambda t : sin(2*pi*freq*t) * H_s_dir
derHs =  lambda t : 2 * pi * freq * cos(2*pi*freq*t) * H_s_dir

# %% [markdown]
# ### c) HTS resistivity model (power law)
#
# In this notebook, the resistivity is defined by a power law as follows
# $$\rho(\lVert \nabla \times H \rVert) =  \frac{E_c}{J_c} \left( \frac{ \lVert \nabla \times H \rVert}{J_c} \right)^{n-1} $$
#
# with
# - $\rho$ the resistivity in $\Omega \cdot m$
# - $H$ the magnetic field in $A\cdot m^{-1}$, so $\lVert \nabla \times H \lVert $ represents the norm of current density
# - $E_c$ the critical electric field parameter in $V\cdot m^{-1}$
# - $J_c$ the critical current density in $A\cdot m^{-2}$
# - $n\gg1$ the resistivity exponent

# %%
n = 20 # 101            # n material parameter
Ec = 1e-4           # local critical current criterion (V/m)
Jc = 2.8e10         # critical current density (A/m²)

## HTS resistivity model
def rho_hts(normcurlH, Ec=Ec, Jc=Jc, n=n):
    """
    Resistivity of the superconductor defined by the power law : 
    rho(||curlH||) = (Ec/Jc)*(||curlH||/Jc)^(n-1)
    """
    return (Ec/Jc)*(normcurlH/Jc)**(n-1)

# %% [markdown]
# _____
# ## 3) Simulation

# %% [markdown]
# ### a) Time loop settings
#
# We use adaptative time loop. When the convergence of the Newton algorithm of the physical solver fails, we reduce the time step; when it converges we increase the time step to accelerate the simulation.

# %%
T_final = 1/freq    # final time = one period 
T_half = T_final/2  # half of the final time

dt_basic = 0.5*T_final / 100
dt =  dt_basic / 2              # first time step
dt_min = dt_basic / 10000       # minimum time step
dt_max = dt_basic               # maximum time step

# %% [markdown]
# ### b) H-formulation
#
# The weak form of the residuals reads
# $$ \mathcal R :
# \left \{
# \begin{array}{lll}
# H_0(\text{curl}, \Omega)^3 & \rightarrow & \mathbb{R} \\
#
# \tilde{h}(t)\;,\; \tilde{h}_0(t)\;,\;v & \mapsto &
# \displaystyle \int_\Omega \mu \partial_t (\tilde{h}(t) + h_s(t)) \cdot v \; \mathrm{d}x + \int_{\Omega} \hat{\rho}(\lVert \text{curl} \; \tilde{h}(t) \rVert ) \text{curl} \; \tilde{h}(t)  \cdot \text{curl} v \; \mathrm{d}x
#
#
# \end{array}
# \right.$$
#
# with
# - $H_0(\text{curl}, \Omega) = \{h(t) \in H(\text{curl}, \Omega), h(t)|_{\Gamma_D} \times n = 0  \; \forall t\}$ the standard function space $H(\text{curl}, \Omega)$  with homogeneous Dirichlet condition on $\Gamma_D$. This function space should be discretized with appropriate edge-elements.
# - $h_0(t) \in \{h(t) \in H(\text{curl}, \Omega), h(t)|_{\Gamma_D} \times n = H_0(t), \text{div}(h(t)) = 0 \; \forall t\}$ the source field, which is imposed and known for every $t$. Moreover $\text{curl}(h_0(t)) = 0,\;\forall t$ in the HTS
# - $\hat{\rho}$ is the resistivity, which is $\rho(\lVert \text{curl} \; \tilde{h}(t) \rVert)$ in the HTS, and $\rho_0 \gg 1$ in the air.
#
# The time derivative is approximated with Cranck-Nicholson scheme. We aim to solve
# $$\forall v \in H_0(\text{curl}, \Omega), \forall t \in [0, t_{max}],\quad \mathcal R(\tilde{h}(t), h_0(t), v) = 0 $$

# %%
## Function space
from ngsolve import HCurl
fes = HCurl(mesh, order=0, dirichlet="out|bottom.*")    # Functional space, order and boundary conditions
dH_tilde = fes.TrialFunction()                          # Unknown function (dofs)
v_test = fes.TestFunction()                             # Test function

## Initial field at t=0
from ngsolve import GridFunction
H_tilde_prev = GridFunction(fes)
## Residual from h-formulation
from ngsolve import curl, sqrt, dx


def residual(H_tilde, v, alpha = 0.5) :
    """
    Residual of H-formulation (alpha = 0.5 => Cranck-Nicolson, alpha = 0 => implicit Euler, alpha = 1 => explicit Euler)
    :param H_tilde: Trial function
    :param v: Test function
    :param time_stepping: Time stepping scheme
    """
    
    curls_H_tilde = alpha * curl(H_tilde_prev) + (1-alpha) * curl(H_tilde)
    normcurlH = sqrt(curls_H_tilde*curls_H_tilde + epsJ)
    curls_v = curl(v)

    res = mu0 * (1/dt_try) * H_tilde* v * dx
    res += -mu0 * (1/dt_try) * H_tilde_prev * v * dx
    res += rho_hts(normcurlH) * (curls_H_tilde) * (curls_v) * dx("hts")
    res += rhoair * (curls_H_tilde) * (curls_v) * dx("air")
    res += mu0 * derHs * v * dx
    return res.Compile()

# %% [markdown]
# ### c) Time loop

# %%
# Initialization

time_list = [0.0]           # list to store time instances
ac_losses_list = [0.0]      # list to store instantanuous AC losses 
steplist = []               # list to store time steps
Ed = 0.0                    # initial mean AC losses (W/m)

t_current = 0.0             # initial time
step = 0                    # time step counter

# %%
import time 
from utils.solver import newton
from ngsolve import Integrate

start = time.perf_counter()

while t_current < T_final:

    converged = False
    dt_try = dt  

    ## If we want to force to pass exactly at the moments T_final/2 and T_final
    if t_current < T_half < t_current + dt_try:
        dt_try = T_half - t_current
        print(f" Adjustment to reach T_final/2 : dt_try = {dt_try:.6e}")
    elif t_current + dt_try > T_final:
        dt_try = T_final - t_current
        print(f" Adjustment of the last step to reach T_final : dt_try = {dt_try:.6e}")

    while not converged:

        t_next = t_current + dt_try
        print(f"\n=== Step {step} ===")
        print(f"Try: t={t_next:.6e}, dt={dt_try:.6e}")

        ### External field and its derivative at the current moment
        Hs = sin(2*pi*freq*t_next) * H_s_dir
        derHs =  2 * pi * freq * cos(2*pi*freq*t_next) * H_s_dir 

        ### Initialisation solution for Newton-Raphson
        sol = GridFunction(fes)
        sol.vec.data = H_tilde_prev.vecs[-1]

        ### Nonlinear resolution with Newton-Raphson
        result = newton(fes = fes, 
                        residual = residual, 
                        initial_guess = sol, 
                        verbosity=1
                        )

        ### Convergence check
        if result["status"] == 0 :
            converged = True
        else:
            new_dt_try = max(dt_try * 0.7, dt_min)  # time step reduction
            print(f"🔻 Newton failed, gradual reduction dt → {new_dt_try:.6e}")
            if new_dt_try == dt_min:
                raise RuntimeError("⛔ Impossible to converge even with minimal dt !")
            dt_try = new_dt_try
            continue

    ## Post-processing for this time step
    H_sol = result["solution"]
    H_t = H_sol + Hs            # Global magnetic field
    J_hts = curl(H_sol)         # induced currents

    ### Instantaneous losses in the superconductor
    ac_losses = Integrate( J_hts * rho_hts(sqrt(J_hts*J_hts + epsJ)) * J_hts, mesh.Materials("hts"), order = 2)

    ### Integration of instantaneous losses per half cycle [T_half, T_final] : explicit Euler
    if t_next > T_half:
        if t_current < T_half:
            Ed += 2 * freq * ac_losses * (t_next - T_half)
        else:
            delta_t_eff = t_next - t_current    
            Ed += 2 * freq * ac_losses * (t_next - t_current)

    ### Store the results
    ac_losses_list.append(ac_losses)
    time_list.append(t_next)    
    steplist.append(dt_try)
    
    print(f"  ✔ Converged | Instant: {t_next:.6f} | Losses: {ac_losses:.6e}")

    ### Update for the next step 
    H_tilde_prev.Set(H_sol)
    t_current = t_next
    step += 1

    ### Adaptive adjustment: increase dt if everything is going well
    dt = min(dt_try * 2, dt_max)  

end = time.perf_counter()
# Out:
# === Step 0 ===
# Try: t=5.000000e-05, dt=5.000000e-05
#   ✔ Converged | Instant: 0.000050 | Losses: 2.014093e-31
#
# === Step 1 ===
# Try: t=1.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000150 | Losses: 2.163646e-21
#
# === Step 2 ===
# Try: t=2.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000250 | Losses: 9.751783e-17
#
# === Step 3 ===
# Try: t=3.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000350 | Losses: 1.116744e-13
#
# === Step 4 ===
# Try: t=4.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000450 | Losses: 2.120788e-11
#
# === Step 5 ===
# Try: t=5.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000550 | Losses: 1.379488e-09
#
# === Step 6 ===
# Try: t=6.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000650 | Losses: 4.368759e-08
#
# === Step 7 ===
# Try: t=7.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000750 | Losses: 7.180912e-07
#
# === Step 8 ===
# Try: t=8.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000850 | Losses: 2.444097e-06
#
# === Step 9 ===
# Try: t=9.500000e-04, dt=1.000000e-04
#   ✔ Converged | Instant: 0.000950 | Losses: 2.199004e-06
#
# === Step 10 ===
# Try: t=1.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001050 | Losses: 2.195750e-06
#
# === Step 11 ===
# Try: t=1.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001150 | Losses: 2.181083e-06
#
# === Step 12 ===
# Try: t=1.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001250 | Losses: 2.367773e-06
#
# === Step 13 ===
# Try: t=1.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001350 | Losses: 3.852213e-06
#
# === Step 14 ===
# Try: t=1.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001450 | Losses: 5.529624e-06
#
# === Step 15 ===
# Try: t=1.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001550 | Losses: 5.749459e-06
#
# === Step 16 ===
# Try: t=1.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001650 | Losses: 5.864564e-06
#
# === Step 17 ===
# Try: t=1.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001750 | Losses: 6.902212e-06
#
# === Step 18 ===
# Try: t=1.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001850 | Losses: 8.984587e-06
#
# === Step 19 ===
# Try: t=1.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.001950 | Losses: 9.952559e-06
#
# === Step 20 ===
# Try: t=2.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002050 | Losses: 1.017352e-05
#
# === Step 21 ===
# Try: t=2.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002150 | Losses: 1.076150e-05
#
# === Step 22 ===
# Try: t=2.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002250 | Losses: 1.247583e-05
#
# === Step 23 ===
# Try: t=2.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002350 | Losses: 1.391821e-05
#
# === Step 24 ===
# Try: t=2.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002450 | Losses: 1.449783e-05
#
# === Step 25 ===
# Try: t=2.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002550 | Losses: 1.492722e-05
#
# === Step 26 ===
# Try: t=2.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002650 | Losses: 1.601628e-05
#
# === Step 27 ===
# Try: t=2.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002750 | Losses: 1.730873e-05
#
# === Step 28 ===
# Try: t=2.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002850 | Losses: 1.801701e-05
#
# === Step 29 ===
# Try: t=2.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.002950 | Losses: 1.833522e-05
#
# === Step 30 ===
# Try: t=3.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003050 | Losses: 1.883122e-05
#
# === Step 31 ===
# Try: t=3.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003150 | Losses: 1.965915e-05
#
# === Step 32 ===
# Try: t=3.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003250 | Losses: 2.028289e-05
#
# === Step 33 ===
# Try: t=3.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003350 | Losses: 2.044836e-05
#
# === Step 34 ===
# Try: t=3.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003450 | Losses: 2.029927e-05
#
# === Step 35 ===
# Try: t=3.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003550 | Losses: 2.009555e-05
#
# === Step 36 ===
# Try: t=3.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003650 | Losses: 2.000235e-05
#
# === Step 37 ===
# Try: t=3.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003750 | Losses: 1.992586e-05
#
# === Step 38 ===
# Try: t=3.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003850 | Losses: 1.966822e-05
#
# === Step 39 ===
# Try: t=3.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.003950 | Losses: 1.916241e-05
#
# === Step 40 ===
# Try: t=4.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004050 | Losses: 1.845434e-05
#
# === Step 41 ===
# Try: t=4.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004150 | Losses: 1.762632e-05
#
# === Step 42 ===
# Try: t=4.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004250 | Losses: 1.674627e-05
#
# === Step 43 ===
# Try: t=4.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004350 | Losses: 1.584529e-05
#
# === Step 44 ===
# Try: t=4.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004450 | Losses: 1.491503e-05
#
# === Step 45 ===
# Try: t=4.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004550 | Losses: 1.393311e-05
#
# === Step 46 ===
# Try: t=4.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004650 | Losses: 1.288772e-05
#
# === Step 47 ===
# Try: t=4.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004750 | Losses: 1.178697e-05
#
# === Step 48 ===
# Try: t=4.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004850 | Losses: 1.065091e-05
#
# === Step 49 ===
# Try: t=4.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.004950 | Losses: 9.504807e-06
#
# === Step 50 ===
# Try: t=5.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005050 | Losses: 8.373728e-06
#
# === Step 51 ===
# Try: t=5.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005150 | Losses: 7.280350e-06
#
# === Step 52 ===
# Try: t=5.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005250 | Losses: 6.244219e-06
#
# === Step 53 ===
# Try: t=5.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005350 | Losses: 5.281606e-06
#
# === Step 54 ===
# Try: t=5.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005450 | Losses: 4.405132e-06
#
# === Step 55 ===
# Try: t=5.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005550 | Losses: 3.623987e-06
#
# === Step 56 ===
# Try: t=5.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005650 | Losses: 2.942904e-06
#
# === Step 57 ===
# Try: t=5.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005750 | Losses: 2.361892e-06
#
# === Step 58 ===
# Try: t=5.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005850 | Losses: 1.875823e-06
#
# === Step 59 ===
# Try: t=5.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.005950 | Losses: 1.475479e-06
#
# === Step 60 ===
# Try: t=6.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006050 | Losses: 1.149186e-06
#
# === Step 61 ===
# Try: t=6.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006150 | Losses: 8.854310e-07
#
# === Step 62 ===
# Try: t=6.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006250 | Losses: 6.738557e-07
#
# === Step 63 ===
# Try: t=6.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006350 | Losses: 5.060193e-07
#
# === Step 64 ===
# Try: t=6.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006450 | Losses: 3.746321e-07
#
# === Step 65 ===
# Try: t=6.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006550 | Losses: 2.733495e-07
#
# === Step 66 ===
# Try: t=6.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006650 | Losses: 1.965095e-07
#
# === Step 67 ===
# Try: t=6.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006750 | Losses: 1.391488e-07
#
# === Step 68 ===
# Try: t=6.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006850 | Losses: 9.701518e-08
#
# === Step 69 ===
# Try: t=6.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.006950 | Losses: 6.656974e-08
#
# === Step 70 ===
# Try: t=7.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007050 | Losses: 4.493046e-08
#
# === Step 71 ===
# Try: t=7.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007150 | Losses: 2.980979e-08
#
# === Step 72 ===
# Try: t=7.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007250 | Losses: 1.942964e-08
#
# === Step 73 ===
# Try: t=7.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007350 | Losses: 1.243248e-08
#
# === Step 74 ===
# Try: t=7.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007450 | Losses: 7.803927e-09
#
# === Step 75 ===
# Try: t=7.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007550 | Losses: 4.802456e-09
#
# === Step 76 ===
# Try: t=7.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007650 | Losses: 2.894948e-09
#
# === Step 77 ===
# Try: t=7.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007750 | Losses: 1.708826e-09
#
# === Step 78 ===
# Try: t=7.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007850 | Losses: 1.018909e-09
#
# === Step 79 ===
# Try: t=7.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.007950 | Losses: 1.535706e-09
#
# === Step 80 ===
# Try: t=8.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008050 | Losses: 1.941979e-08
#
# === Step 81 ===
# Try: t=8.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008150 | Losses: 2.551560e-07
#
# === Step 82 ===
# Try: t=8.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008250 | Losses: 1.526854e-06
#
# === Step 83 ===
# Try: t=8.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008350 | Losses: 2.040856e-06
#
# === Step 84 ===
# Try: t=8.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008450 | Losses: 2.043341e-06
#
# === Step 85 ===
# Try: t=8.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008550 | Losses: 2.081753e-06
#
# === Step 86 ===
# Try: t=8.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008650 | Losses: 2.112565e-06
#
# === Step 87 ===
# Try: t=8.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008750 | Losses: 2.143851e-06
#
# === Step 88 ===
# Try: t=8.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008850 | Losses: 2.173297e-06
#
# === Step 89 ===
# Try: t=8.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.008950 | Losses: 2.197694e-06
#
# === Step 90 ===
# Try: t=9.050000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009050 | Losses: 2.222164e-06
#
# === Step 91 ===
# Try: t=9.150000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009150 | Losses: 2.275016e-06
#
# === Step 92 ===
# Try: t=9.250000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009250 | Losses: 2.780522e-06
#
# === Step 93 ===
# Try: t=9.350000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009350 | Losses: 5.131626e-06
#
# === Step 94 ===
# Try: t=9.450000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009450 | Losses: 6.436256e-06
#
# === Step 95 ===
# Try: t=9.550000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009550 | Losses: 6.475629e-06
#
# === Step 96 ===
# Try: t=9.650000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009650 | Losses: 6.558891e-06
#
# === Step 97 ===
# Try: t=9.750000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009750 | Losses: 6.553464e-06
#
# === Step 98 ===
# Try: t=9.850000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009850 | Losses: 6.601403e-06
#
# === Step 99 ===
# Try: t=9.950000e-03, dt=1.000000e-04
#   ✔ Converged | Instant: 0.009950 | Losses: 6.923199e-06
#  Adjustment to reach T_final/2 : dt_try = 5.000000e-05
#
# === Step 100 ===
# Try: t=1.000000e-02, dt=5.000000e-05
#   ✔ Converged | Instant: 0.010000 | Losses: 7.745444e-06
#
# === Step 101 ===
# Try: t=1.010000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010100 | Losses: 1.077677e-05
#
# === Step 102 ===
# Try: t=1.020000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010200 | Losses: 1.237877e-05
#
# === Step 103 ===
# Try: t=1.030000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010300 | Losses: 1.262682e-05
#
# === Step 104 ===
# Try: t=1.040000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010400 | Losses: 1.265179e-05
#
# === Step 105 ===
# Try: t=1.050000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010500 | Losses: 1.262245e-05
#
# === Step 106 ===
# Try: t=1.060000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010600 | Losses: 1.275587e-05
#
# === Step 107 ===
# Try: t=1.070000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010700 | Losses: 1.439080e-05
#
# === Step 108 ===
# Try: t=1.080000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010800 | Losses: 1.767227e-05
#
# === Step 109 ===
# Try: t=1.090000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.010900 | Losses: 1.928890e-05
#
# === Step 110 ===
# Try: t=1.100000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011000 | Losses: 1.963578e-05
#
# === Step 111 ===
# Try: t=1.110000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011100 | Losses: 1.959469e-05
#
# === Step 112 ===
# Try: t=1.120000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011200 | Losses: 1.953020e-05
#
# === Step 113 ===
# Try: t=1.130000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011300 | Losses: 2.025400e-05
#
# === Step 114 ===
# Try: t=1.140000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011400 | Losses: 2.299563e-05
#
# === Step 115 ===
# Try: t=1.150000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011500 | Losses: 2.532644e-05
#
# === Step 116 ===
# Try: t=1.160000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011600 | Losses: 2.618253e-05
#
# === Step 117 ===
# Try: t=1.170000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011700 | Losses: 2.622566e-05
#
# === Step 118 ===
# Try: t=1.180000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011800 | Losses: 2.602023e-05
#
# === Step 119 ===
# Try: t=1.190000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.011900 | Losses: 2.621544e-05
#
# === Step 120 ===
# Try: t=1.200000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012000 | Losses: 2.798168e-05
#
# === Step 121 ===
# Try: t=1.210000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012100 | Losses: 3.032664e-05
#
# === Step 122 ===
# Try: t=1.220000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012200 | Losses: 3.154929e-05
#
# === Step 123 ===
# Try: t=1.230000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012300 | Losses: 3.175894e-05
#
# === Step 124 ===
# Try: t=1.240000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012400 | Losses: 3.140451e-05
#
# === Step 125 ===
# Try: t=1.250000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012500 | Losses: 3.082006e-05
#
# === Step 126 ===
# Try: t=1.260000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012600 | Losses: 3.038501e-05
#
# === Step 127 ===
# Try: t=1.270000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012700 | Losses: 3.069483e-05
#
# === Step 128 ===
# Try: t=1.280000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012800 | Losses: 3.181065e-05
#
# === Step 129 ===
# Try: t=1.290000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.012900 | Losses: 3.270206e-05
#
# === Step 130 ===
# Try: t=1.300000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013000 | Losses: 3.287973e-05
#
# === Step 131 ===
# Try: t=1.310000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013100 | Losses: 3.245025e-05
#
# === Step 132 ===
# Try: t=1.320000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013200 | Losses: 3.162153e-05
#
# === Step 133 ===
# Try: t=1.330000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013300 | Losses: 3.057731e-05
#
# === Step 134 ===
# Try: t=1.340000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013400 | Losses: 2.948888e-05
#
# === Step 135 ===
# Try: t=1.350000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013500 | Losses: 2.854706e-05
#
# === Step 136 ===
# Try: t=1.360000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013600 | Losses: 2.789631e-05
#
# === Step 137 ===
# Try: t=1.370000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013700 | Losses: 2.745180e-05
#
# === Step 138 ===
# Try: t=1.380000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013800 | Losses: 2.693472e-05
#
# === Step 139 ===
# Try: t=1.390000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.013900 | Losses: 2.616238e-05
#
# === Step 140 ===
# Try: t=1.400000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014000 | Losses: 2.511707e-05
#
# === Step 141 ===
# Try: t=1.410000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014100 | Losses: 2.385039e-05
#
# === Step 142 ===
# Try: t=1.420000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014200 | Losses: 2.242733e-05
#
# === Step 143 ===
# Try: t=1.430000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014300 | Losses: 2.090572e-05
#
# === Step 144 ===
# Try: t=1.440000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014400 | Losses: 1.933381e-05
#
# === Step 145 ===
# Try: t=1.450000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014500 | Losses: 1.774920e-05
#
# === Step 146 ===
# Try: t=1.460000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014600 | Losses: 1.618141e-05
#
# === Step 147 ===
# Try: t=1.470000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014700 | Losses: 1.465139e-05
#
# === Step 148 ===
# Try: t=1.480000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014800 | Losses: 1.317267e-05
#
# === Step 149 ===
# Try: t=1.490000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.014900 | Losses: 1.175287e-05
#
# === Step 150 ===
# Try: t=1.500000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015000 | Losses: 1.039620e-05
#
# === Step 151 ===
# Try: t=1.510000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015100 | Losses: 9.106199e-06
#
# === Step 152 ===
# Try: t=1.520000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015200 | Losses: 7.888502e-06
#
# === Step 153 ===
# Try: t=1.530000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015300 | Losses: 6.751021e-06
#
# === Step 154 ===
# Try: t=1.540000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015400 | Losses: 5.703321e-06
#
# === Step 155 ===
# Try: t=1.550000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015500 | Losses: 4.754837e-06
#
# === Step 156 ===
# Try: t=1.560000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015600 | Losses: 3.912910e-06
#
# === Step 157 ===
# Try: t=1.570000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015700 | Losses: 3.181096e-06
#
# === Step 158 ===
# Try: t=1.580000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015800 | Losses: 2.557911e-06
#
# === Step 159 ===
# Try: t=1.590000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.015900 | Losses: 2.036565e-06
#
# === Step 160 ===
# Try: t=1.600000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016000 | Losses: 1.606423e-06
#
# === Step 161 ===
# Try: t=1.610000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016100 | Losses: 1.254668e-06
#
# === Step 162 ===
# Try: t=1.620000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016200 | Losses: 9.694016e-07
#
# === Step 163 ===
# Try: t=1.630000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016300 | Losses: 7.399743e-07
#
# === Step 164 ===
# Try: t=1.640000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016400 | Losses: 5.575992e-07
#
# === Step 165 ===
# Try: t=1.650000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016500 | Losses: 4.145501e-07
#
# === Step 166 ===
# Try: t=1.660000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016600 | Losses: 3.040061e-07
#
# === Step 167 ===
# Try: t=1.670000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016700 | Losses: 2.198458e-07
#
# === Step 168 ===
# Try: t=1.680000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016800 | Losses: 1.567429e-07
#
# === Step 169 ===
# Try: t=1.690000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.016900 | Losses: 1.101332e-07
#
# === Step 170 ===
# Try: t=1.700000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017000 | Losses: 7.623484e-08
#
# === Step 171 ===
# Try: t=1.710000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017100 | Losses: 5.195721e-08
#
# === Step 172 ===
# Try: t=1.720000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017200 | Losses: 3.484596e-08
#
# === Step 173 ===
# Try: t=1.730000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017300 | Losses: 2.298386e-08
#
# === Step 174 ===
# Try: t=1.740000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017400 | Losses: 1.490134e-08
#
# === Step 175 ===
# Try: t=1.750000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017500 | Losses: 9.490514e-09
#
# === Step 176 ===
# Try: t=1.760000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017600 | Losses: 5.934232e-09
#
# === Step 177 ===
# Try: t=1.770000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017700 | Losses: 3.640557e-09
#
# === Step 178 ===
# Try: t=1.780000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017800 | Losses: 2.193570e-09
#
# === Step 179 ===
# Try: t=1.790000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.017900 | Losses: 1.437350e-09
#
# === Step 180 ===
# Try: t=1.800000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018000 | Losses: 4.354655e-09
#
# === Step 181 ===
# Try: t=1.810000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018100 | Losses: 6.108592e-08
#
# === Step 182 ===
# Try: t=1.820000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018200 | Losses: 6.387986e-07
#
# === Step 183 ===
# Try: t=1.830000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018300 | Losses: 1.989568e-06
#
# === Step 184 ===
# Try: t=1.840000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018400 | Losses: 2.027211e-06
#
# === Step 185 ===
# Try: t=1.850000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018500 | Losses: 2.064319e-06
#
# === Step 186 ===
# Try: t=1.860000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018600 | Losses: 2.097513e-06
#
# === Step 187 ===
# Try: t=1.870000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018700 | Losses: 2.129350e-06
#
# === Step 188 ===
# Try: t=1.880000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018800 | Losses: 2.157372e-06
#
# === Step 189 ===
# Try: t=1.890000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.018900 | Losses: 2.183741e-06
#
# === Step 190 ===
# Try: t=1.900000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019000 | Losses: 2.210274e-06
#
# === Step 191 ===
# Try: t=1.910000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019100 | Losses: 2.239068e-06
#
# === Step 192 ===
# Try: t=1.920000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019200 | Losses: 2.366473e-06
#
# === Step 193 ===
# Try: t=1.930000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019300 | Losses: 3.578875e-06
#
# === Step 194 ===
# Try: t=1.940000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019400 | Losses: 5.944551e-06
#
# === Step 195 ===
# Try: t=1.950000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019500 | Losses: 6.464608e-06
#
# === Step 196 ===
# Try: t=1.960000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019600 | Losses: 6.520145e-06
#
# === Step 197 ===
# Try: t=1.970000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019700 | Losses: 6.556881e-06
#
# === Step 198 ===
# Try: t=1.980000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019800 | Losses: 6.572042e-06
#
# === Step 199 ===
# Try: t=1.990000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.019900 | Losses: 6.651614e-06
#
# === Step 200 ===
# Try: t=2.000000e-02, dt=1.000000e-04
#   ✔ Converged | Instant: 0.020000 | Losses: 7.525951e-06
#  Adjustment of the last step to reach T_final : dt_try = 5.898060e-17
#
# === Step 201 ===
# Try: t=2.000000e-02, dt=5.898060e-17
#   ✔ Converged | Instant: 0.020000 | Losses: 7.525951e-06

# %% [markdown]
# _______
# ## 4) Final results
#
# We finally display the results and compare with COMSOL computations.

# %%
print(f"\n{'='*50}")
print("Final results")
print(f"{'='*50}")
print(f"Total simulation time : {end-start:.3f} s")
print(f"Average losses Ed (half cycle) : {Ed:.6e} W/m")

## Data plot
from utils.trace import plot_result
plot_result(time_list, ac_losses_list, 
            filename_comsol = "results_COMSOL/2D/external_field/AC_Losses_"+str(int(Bmax*1000))+"mT_quarter.txt")
# Out:
# ==================================================
# Final results
# ==================================================
# Total simulation time : 4.663 s
# Average losses Ed (half cycle) : 1.280560e-05 W/m

# %%
import numpy as np
X = np.linspace(0, 2e-3, 200)
J = []
for x in X:
    J.append(curl(H_sol)(mesh(x,0))[0] / 1e6)

import matplotlib.pyplot as plt 
plt.plot(X*1000,J)
plt.grid(); plt.xlabel("x (mm)"); plt.ylabel("J (A/mm²)")
plt.title("Current density distribution at t= T_final")
plt.show()

# %%
from ngsolve import solvers

help(solvers)

help(solvers.SuperLU)
# Out:
# Help on module ngsolve.solvers in ngsolve:
#
# NAME
#     ngsolve.solvers
#
# FILE
#     c:\users\theodore\miniconda3\envs\ngsolve-env\lib\site-packages\ngsolve\solvers.py
#
#
# Help on class SuperLU in module ngsolve.directsolvers:
#
# class SuperLU(ngsolve.la.BaseMatrix)
#  |  SuperLU(a, freedofs: pyngcore.pyngcore.BitArray = None)
#  |
#  |  Method resolution order:
#  |      SuperLU
#  |      ngsolve.la.BaseMatrix
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Mult(self, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector)
#  |      Mult(self: ngsolve.la.BaseMatrix, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |  Update(self)
#  |      Update(self: ngsolve.la.BaseMatrix) -> None
#  |
#  |      Update matrix
#  |
#  |  __init__(self, a, freedofs: pyngcore.pyngcore.BitArray = None)
#  |      __init__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __init__(self: ngsolve.la.BaseMatrix) -> None
#  |
#  |      2. __init__(self: ngsolve.la.BaseMatrix, arg0: ngsolve.la.BaseVector) -> None
#  |
#  |      3. __init__(self: ngsolve.la.BaseMatrix, arg0: ngsolve.la.MultiVector) -> None
#  |
#  |      4. __init__(self: ngsolve.la.BaseMatrix, arg0: ngsolve.bla.MatrixD) -> None
#  |
#  |      5. __init__(self: ngsolve.la.BaseMatrix, arg0: object) -> None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ngsolve.la.BaseMatrix:
#  |
#  |  AsVector(...)
#  |      AsVector(self: ngsolve.la.BaseMatrix) -> ngsolve.la.BaseVector
#  |
#  |      Interprets the matrix values as a vector
#  |
#  |  CreateColVector(...)
#  |      CreateColVector(self: ngsolve.la.BaseMatrix) -> ngsolve.la.BaseVector
#  |
#  |  CreateDeviceMatrix(...)
#  |      CreateDeviceMatrix(self: ngsolve.la.BaseMatrix) -> BaseMatrix
#  |
#  |  CreateMatrix(...)
#  |      CreateMatrix(self: ngsolve.la.BaseMatrix) -> BaseMatrix
#  |
#  |      Create matrix of same dimension and same sparsestructure
#  |
#  |  CreateRowVector(...)
#  |      CreateRowVector(self: ngsolve.la.BaseMatrix) -> ngsolve.la.BaseVector
#  |
#  |  CreateSparseMatrix(...)
#  |      CreateSparseMatrix(self: ngsolve.la.BaseMatrix) -> ngla::BaseSparseMatrix
#  |
#  |  CreateVector(...)
#  |      CreateVector(self: ngsolve.la.BaseMatrix, colvector: bool = False) -> ngsolve.la.BaseVector
#  |
#  |  GetInverseType(...)
#  |      GetInverseType(self: ngsolve.la.BaseMatrix) -> str
#  |
#  |  GetOperatorInfo(...)
#  |      GetOperatorInfo(self: ngsolve.la.BaseMatrix) -> str
#  |
#  |  Inverse(...)
#  |      Inverse(self: ngsolve.la.BaseMatrix, freedofs: pyngcore.pyngcore.BitArray = None, inverse: Union[None, str, object] = None, flags: pyngcore.pyngcore.Flags = <pyngcore.pyngcore.Flags object at 0x000002325596B630>) -> BaseMatrix
#  |
#  |      Calculate inverse of sparse matrix
#  |      Parameters:
#  |
#  |      freedofs : BitArray
#  |        If set, invert only the rows/columns the matrix defined by the bit array, otherwise invert the whole matrix
#  |
#  |      inverse : string
#  |        Solver to use, allowed values are:
#  |          sparsecholesky - internal solver of NGSolve for symmetric matrices
#  |          umfpack        - solver by Suitesparse/UMFPACK (if NGSolve was configured with USE_UMFPACK=ON)
#  |          pardiso        - PARDISO, either provided by libpardiso (USE_PARDISO=ON) or Intel MKL (USE_MKL=ON).
#  |                           If neither Pardiso nor Intel MKL was linked at compile-time, NGSolve will look
#  |                           for libmkl_rt in LD_LIBRARY_PATH (Unix) or PATH (Windows) at run-time.
#  |
#  |  MultAdd(...)
#  |      MultAdd(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. MultAdd(self: ngsolve.la.BaseMatrix, value: float, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |      2. MultAdd(self: ngsolve.la.BaseMatrix, value: complex, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |  MultScale(...)
#  |      MultScale(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. MultScale(self: ngsolve.la.BaseMatrix, value: float, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |      2. MultScale(self: ngsolve.la.BaseMatrix, value: complex, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |  MultTrans(...)
#  |      MultTrans(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. MultTrans(self: ngsolve.la.BaseMatrix, value: float, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |      2. MultTrans(self: ngsolve.la.BaseMatrix, value: complex, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |  MultTransAdd(...)
#  |      MultTransAdd(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. MultTransAdd(self: ngsolve.la.BaseMatrix, value: float, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |      2. MultTransAdd(self: ngsolve.la.BaseMatrix, value: complex, x: ngsolve.la.BaseVector, y: ngsolve.la.BaseVector) -> None
#  |
#  |  ToDense(...)
#  |      ToDense(self: ngsolve.la.BaseMatrix) -> object
#  |
#  |  __add__(...)
#  |      __add__(self: BaseMatrix, mat: BaseMatrix) -> BaseMatrix
#  |
#  |  __iadd__(...)
#  |      __iadd__(self: ngsolve.la.BaseMatrix, mat: ngsolve.la.BaseMatrix) -> None
#  |
#  |  __matmul__(...)
#  |      __matmul__(self: BaseMatrix, mat: BaseMatrix) -> BaseMatrix
#  |
#  |  __mul__(...)
#  |      __mul__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __mul__(self: BaseMatrix, arg0: ngsolve.la.BaseVector) -> ngla::DynamicVectorExpression
#  |
#  |      2. __mul__(self: BaseMatrix, arg0: ngsolve.la.MultiVector) -> ngsolve.la.MultiVectorExpr
#  |
#  |  __neg__(...)
#  |      __neg__(self: BaseMatrix) -> BaseMatrix
#  |
#  |  __radd__(...)
#  |      __radd__(self: BaseMatrix, arg0: int) -> BaseMatrix
#  |
#  |  __rmul__(...)
#  |      __rmul__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __rmul__(self: BaseMatrix, value: float) -> BaseMatrix
#  |
#  |      2. __rmul__(self: BaseMatrix, value: complex) -> BaseMatrix
#  |
#  |  __str__(...)
#  |      __str__(self: ngsolve.la.BaseMatrix) -> str
#  |
#  |  __sub__(...)
#  |      __sub__(self: BaseMatrix, mat: BaseMatrix) -> BaseMatrix
#  |
#  |  __timing__(...)
#  |      __timing__(self: ngsolve.la.BaseMatrix, runs: int = 10) -> float
#  |
#  |  matvec(...)
#  |      matvec(self: BaseMatrix, arg0: ngsolve.la.BaseVector) -> ngsolve.la.BaseVector
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from ngsolve.la.BaseMatrix:
#  |
#  |  H
#  |      Return conjugate transpose of matrix (WIP, only partially supported)
#  |
#  |  T
#  |      Return transpose of matrix
#  |
#  |  comm
#  |
#  |  dtype
#  |
#  |  height
#  |      Height of the matrix
#  |
#  |  is_complex
#  |      is the matrix complex-valued ?
#  |
#  |  local_mat
#  |
#  |  nze
#  |      number of non-zero elements
#  |
#  |  shape
#  |
#  |  width
#  |      Width of the matrix
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#  |      Create and return a new object.  See help(type) for accurate signature.
