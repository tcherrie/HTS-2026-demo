# %% [markdown]
# # HTS 2026 demo - Index
#
# ## 2D tape
# - External field excitation: [link to notebook](2D_tape_external_field.ipynb)
# - Transport current excitation: TODO
#
# ## 3D bulk
# - TODO

# %% [markdown]
# _________
# ### Contacts
#
# - Zakaria Houta  (zakaria.houta@centralesupelec.fr)
# - Théodore Cherrière  (theodore.cherriere@centralesupelec.fr)
# - Loïc Quéval (loic.queval@centralesupelec.fr)
