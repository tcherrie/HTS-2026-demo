# %% [markdown]
# # HTS 2026 - Index
#
# ## 2D tape
# - Excited with an external field : [link to notebook](2D_tape_external_field.ipynb)
# - Excited with transport current : TODO
#
# ## 3D bulk
# - TODO
